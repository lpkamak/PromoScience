# %% [markdown]
# # **Introduction to Python**
# Welcome to Google Colaboratory. Here you will be able to execute Python commands easily. The version used here is Python 3.7.11.
#
# You can check your Python version at the command line by running
# `!python --version`
# Follow the given instructions carefully:

# %%
# !python --version
# Out:
# Python 3.7.12

# %% [markdown]
# A tradition in computer science for your first program is to write a program which outputs a simple phrase: `Hello World!`. To complete this tradition, input the following into the cell below:
#
# ```python
# print("Hello World!")
#  ```

# %%
print("Hello Preethi ")
# Out:
# Hello Preethi

# %% [markdown]
# **Calculating with Python**
#
# Python can be used to solve simple to complex arithmetic equations. Lets try some simple expressions

# %%
1 + 2
# Out:
# 3

# %%
100000 - 1
# Out:
# 99999

# %% [markdown]
# In **Python Operators** , We use the asterisk symbol (*) instead of a multiplication sign (×) and the forward slash (/) is used for division

# %%
8 * 3.57
# Out:
# 28.56

# %%
10000/3
# Out:
# 3333.3333333333335

# %% [markdown]
# # Variables
# This is Python’s way of “remembering” a value. Variables can be numbers like integers or decimals , or even words and characters, which are known as “strings”.
# Let's write a program to find the total amount of your pen and pencil using variable concept.

# %%
pen =100

pencil = 19

total = pen + pencil

print(total)
# Out:
# 119

# %% [markdown]
# # Let's take a break
#
# Exercises:
# Quiz :
#
#
# *   Python is named after ?
# 1.  Snake
# 2.  TV Show
#
# *   List item
#
# Variable is used to store -----

# %% [markdown]
# # Input & Output

# %% [markdown]
# Lets create a simple program to ask someone their name and store it.
# INPUT asks a question. OUTPUT prints a message on screen. The steps given below will be executed sequentially in a program.

# %% [markdown]
# 1.   OUTPUT 'What is your name?'
# 2.   INPUT user inputs their name
# 3.   STORE the user's input in the name variable

# %%
print("What is your name ?")
name = input()
# Out:
# What is your name ?
# Preethi

# %% [markdown]
# ![Variable.JPG](data:image/jpeg;base64,...)

# %%
# Write program to print a congratulatory message 
print (name);
print ("has completed her first Python Program");
# Out:
# Preethi
# has completed her first Python Program

# %%
#Concatenation : Definition

print ("Congratulations ! " + name + " has completed her first Python Program")
# More Practice print messages - Happy Birthday , Welcome back to school , Hope you have a great year ....
# Out:
# Congratulations ! Preethi has completed her first Python Program
